# %% [markdown]
# Solution Question 1
#
# BIBLIOGRAPHY:
#
# 1.Sornmo Leif, Laguna Pabilo. "ELECTROCARDIOGRAM(ECG) SIGNAL PROCESSING" 23 October 2017. <www.googlescholar.com>
#
# 2.Parak J.,Havlik J.. "ECG signal processing and heart rate frequency detection methods" 23 October 2017. <www.googlescholar.com>
#
# 3.Billauer,E. "Peakdet:Peak detection using MATLAB."  September,2008. [cit: 2017-10-23]. <www.billaeur.co.il/peakdet.html>
#
# 4.Curiel Laura., "Filtering.ipynb and FourierTransform.ipynb" September,2017. [cit: 2017-10-01]

# %% [markdown]
# Solution Question 2
#
# INTRODUCTION
#
# Electrocardiogram (ECG) represents electrical activity of human heart. ECG is composite from 5 waves - P, Q, R, S and T.  This signal could be measured by electrodes from human body in typical engagement. Signals from these electrodes are brought to simple electrical circuits with amplifiers and analogue – digital converters.
#
# The main problem of digitalized signal is interference with other noisy signals like power supply network 50 Hz frequency and breathing muscle artefacts. These noisy elements have to be removed before the signal is used for next data processing like heart rate frequency detection. Digital filters and signal processing should be designed very effective for next real-time applications in embedded devices.
#
# Heart rate frequency is very important health status information. The frequency measurement is used in many medical or sport applications like stress tests or life treating situation prediction. One of possible ways how to get heart rate frequency is compute it from the ECG signal. Heart rate frequency can be detected from ECG signal by many methods and algorithms.
#
# Electrocardiographic signals may be recorded on a long timescale (i.e., several days) for the purpose of identifying intermittently occurring disturbances in the heart rhythm. As a result, the produced ECG recording amounts to huge data sizes that quickly fill up available storage space. Transmission of signals across public telephone networks is another application in which large amounts of data are involved. For both situations, data compression is an essential operation and, consequently, represents yet another objective of ECG signal processing.
#
# Signal processing has contributed significantly to a new understanding of the ECG and its dynamic properties as expressed by changes in rhythm and beat morphology. For example, techniques have been developed that characterize oscillations related to the cardiovascular system and reflected by subtle variations in heart rate. The detection of low-level, alternating changes in T wave amplitude is another example of oscillatory behavior that has been established as an indicator of increased risk for sudden, life-threatening arrhythmias. Neither of these two oscillatory signal properties can be perceived by the naked eye from a standard ECG printout.
#
# Common to all types of ECG analysis—whether it concerns resting ECG interpretation, stress testing, ambulatory monitoring, or intensive care monitoring—is a basic set of algorithms that condition the signal with respect to different types of noise and artifacts, detect heartbeats, extract basic ECG measurements of wave amplitudes and durations, and compress the data for efficient storage or transmission.
#
# Algorithms for basic ECG signal processing. The timing information produced by the QRS detector may be fed to the blocks for noise filtering and data compression (indicated by gray arrows) to improve their respective performance. The output of the upper branch is the conditioned ECG signal and related temporal information, including the occurrence time of each heartbeat and the onset and end of each wave.
#
# Operated in sequential order, information on the occurrence time of a heartbeat, as produced by the QRS detector, is sometimes incorporated into the other algorithms to improve performance. The complexity of each algorithm varies from application to application so that, for example, noise filtering performed in ambulatory monitoring is much more sophisticated than that required in resting ECG analysis.
#
# Once the information produced by the basic set of algorithms is available, a wide range of ECG applications exist where it is of interest to use signal processing for quantifying heart rhythm and beat morphology properties.

# %%
#Question 3
# We will firstly initialize and call matplotlib for plotting and we mention that those plota are required inline
# %matplotlib inline
# We will import all the packages that will allow to perform all the operations like mathematics,array and plotting
import scipy as Sci
import scipy.signal as Sig
import numpy as np
import pylab as pl
import matplotlib.pyplot as plt

# We will open the given file
f= open('aami3a.dat','rb')
AllSignal=np.fromfile(f,count=-1,dtype=np.uint16)
print('/n The length of the file is:'+str(len(AllSignal))+' as expected from 10000 samples* 100 lines')
x=np.arange(0,10000/720e6,1/720e6)
print('/n The length of the time array is:'+str(len(x)))
plt.plot(x,AllSignal[:10000])
plt.title('ECG Acquired')
plt.xlabel('Time')
plt.ylabel('ECG Signal')
plt.ticklabel_format(style='sci',axis='x',scilimits=(0,0))
f.close()
# Out:
# /n The length of the file is:43081 as expected from 10000 samples* 100 lines
# /n The length of the time array is:10000

# %%
totlines=np.arange(100)
for index in totlines:
    Signal=AllSignal[index*10000:(index+1)*10000]
    plt.plot(x,AllSignal[index*10000:(index+1)*10000])
    plt.xlabel('Time')
    plt.ylabel('ECG Signal')
    plt.ticklabel_format(style='sci',axis='x',scilimits=(0,0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-7354172022d3> in <module>()
#       2 for index in totlines:
#       3     Signal=AllSignal[index*10000:(index+1)*10000]
# ----> 4     plt.plot(x,AllSignal[index*10000:(index+1)*10000])
#       5     plt.xlabel('Time')
#       6     plt.ylabel('ECG Signal')
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# ...

# %% [markdown]
# Solution Question 5:
#
# If a person is having an average heart rate between 60 and 100 beats per minute, we need about 46 samples to obtain 5 beats in the signal.

# %%
Firstline=AllSignal[:10000]
plt.subplot(211)
plt.plot(x,Firstline)
plt.ylabel('ECG Signal')
plt.ticklabel_format(style='sci',axis='x',scilimits=(0,0))

# %%
 dataF=Firstline-np.mean(Firstline)
L=len(dataF)
f=np.arange(0,720e6/2,720e6/10000)
Y=np.fft.fft(dataF)
PyyClean=abs(Y)/L
plt.subplot(121)
plt.plot(f,PyyClean[:5000])
plt.title('DFT of clean line')
plt.ticklabel_format(style='sci',axis='x',scilimits=(0,0))
#Zooming in
inx=np.where(f>10e6)
inx=inx[0]
plt.subplot(122)
plt.plot(f[:inx[0]],PyyClean[:inx[0]])
plt.title('DFT of Clean ECG')
plt.ticklabel_format(style='sci',axis='x',scilimits=(0,0))

# %% [markdown]
# Solution Question 8
#
# The heart rate for this individual was high as compared to normal person because he/she is having 14 peaks in one second ECG.

# %% [markdown]
# Solution Question 10
#
# The frequency at which the maximum is observed is 4.5 by looking at DFT.

# %% [markdown]
# Solution Question 11
#
# heart rate= beats/minutes

# %% [markdown]
# Solution Question 12
#
# Peaks in ECG mostly said as "P" point PQRST graph of ECG indicate the electrical impulse in the upper chambers of the heart whereas "QRS" tells the electrical impulse in lower chambers. "T" shows the heart's return to rest.

# %% [markdown]
# Solution Question 13
#
# Filters do effect the magnitude and phase of the signal but since here we are having no any relation with phase so the any filter which effects phase but not the magnitude will be worth in this case.
# If i need to do so i would use linear-phase band-pass filter since we can have linear phase in that as well as the required conditioning in magnitude.

# %%
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
# applying butterworth low-pass filter
cutoff=100
fs=750
order=4
nyq=fs*0.5
g=cutoff/nyq
print(g)

b,a=butter(4,g,btype='lowpass',analog=False)
w,h=signal.freqz(b,a)
    
    
plt.plot(w, 20 * np.log10(abs(h)))
plt.xscale('log')
plt.title('Butterworth filter frequency response')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
plt.margins(0, 0.1)
plt.grid(which='both', axis='both')
plt.axvline(100, color='green') # cutoff frequency
plt.show()
# Out:
# 0.266666666667
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4ab71dffe797> in <module>()
#      11 print(g)
#      12
# ---> 13 b,a=butter(4,g,btype='lowpass',analog=False)
#      14 w,h=signal.freqz(b,a)
#      15
#
# NameError: name 'butter' is not defined

# %% [markdown]
# Solution Question 17
#
# Linear phase band pass is so because if we keep the phase linear there would be to avoid power line interference, band-pass is to cut the required frequency band instead of going with lower or higher frequencies since baseline wander is also main consideration.we have to keep these in mind during deciding a filter.
